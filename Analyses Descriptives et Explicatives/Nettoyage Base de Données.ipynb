# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Contexte-de-l'étude" data-toc-modified-id="Contexte-de-l'étude-1">Contexte de l'étude</a></span></li><li><span><a href="#1.-Nettoyage-de-la-base-de-données" data-toc-modified-id="1.-Nettoyage-de-la-base-de-données-2">1. Nettoyage de la base de données</a></span><ul class="toc-item"><li><span><a href="#1.1-Importation-des-librairies,-fonctions-et-données" data-toc-modified-id="1.1-Importation-des-librairies,-fonctions-et-données-2.1">1.1 Importation des librairies, fonctions et données</a></span><ul class="toc-item"><li><span><a href="#1.1.1.-Importation-du-jeu-de-données" data-toc-modified-id="1.1.1.-Importation-du-jeu-de-données-2.1.1">1.1.1. Importation du jeu de données</a></span></li><li><span><a href="#1.1.2.-Description-du-jeu-de-données" data-toc-modified-id="1.1.2.-Description-du-jeu-de-données-2.1.2">1.1.2. Description du jeu de données</a></span></li></ul></li><li><span><a href="#1.2-Identification,-quantification-et-suppression-des-variables-(colonnes)-et-des-produits-(lignes)-ayant-trop-de-valeurs-manquantes" data-toc-modified-id="1.2-Identification,-quantification-et-suppression-des-variables-(colonnes)-et-des-produits-(lignes)-ayant-trop-de-valeurs-manquantes-2.2">1.2 Identification, quantification et suppression des variables (colonnes) et des produits (lignes) ayant trop de valeurs manquantes</a></span><ul class="toc-item"><li><span><a href="#1.2.1-Quantification-des-valeurs-manquantes" data-toc-modified-id="1.2.1-Quantification-des-valeurs-manquantes-2.2.1">1.2.1 Quantification des valeurs manquantes</a></span></li><li><span><a href="#1.2.2-Identification,-quantification-et-suppression-des-variables-ayant-un-taux-de-remplissage-trop-bas" data-toc-modified-id="1.2.2-Identification,-quantification-et-suppression-des-variables-ayant-un-taux-de-remplissage-trop-bas-2.2.2">1.2.2 Identification, quantification et suppression des variables ayant un taux de remplissage trop bas</a></span></li><li><span><a href="#1.2.3-Identification-et-suppression-des-variables-redondantes-ou-non-pertinentes-(d'après-leur-description)" data-toc-modified-id="1.2.3-Identification-et-suppression-des-variables-redondantes-ou-non-pertinentes-(d'après-leur-description)-2.2.3">1.2.3 Identification et suppression des variables redondantes ou non pertinentes (d'après leur description)</a></span></li><li><span><a href="#1.2.4-Quantification-et-suppression-des-lignes-ayant-trop-de-valeurs-manquantes" data-toc-modified-id="1.2.4-Quantification-et-suppression-des-lignes-ayant-trop-de-valeurs-manquantes-2.2.4">1.2.4 Quantification et suppression des lignes ayant trop de valeurs manquantes</a></span></li></ul></li><li><span><a href="#1.3-Traitement-des-variables-qualitatives" data-toc-modified-id="1.3-Traitement-des-variables-qualitatives-2.3">1.3 Traitement des variables qualitatives</a></span><ul class="toc-item"><li><span><a href="#1.3.1.-Remplacement-des-valeurs-manquantes-des-variables-qualitatives" data-toc-modified-id="1.3.1.-Remplacement-des-valeurs-manquantes-des-variables-qualitatives-2.3.1">1.3.1. Remplacement des valeurs manquantes des variables qualitatives</a></span></li><li><span><a href="#1.3.2.-Quantification-et-suppression-des-produits-impossible-à-identifier" data-toc-modified-id="1.3.2.-Quantification-et-suppression-des-produits-impossible-à-identifier-2.3.2">1.3.2. Quantification et suppression des produits impossible à identifier</a></span></li><li><span><a href="#1.3.3.-Quantification-et-suppression-des-lignes-dupliquées" data-toc-modified-id="1.3.3.-Quantification-et-suppression-des-lignes-dupliquées-2.3.3">1.3.3. Quantification et suppression des lignes dupliquées</a></span></li><li><span><a href="#1.3.4.-Suppression-des-variables-qualitatives-non-pertinentes" data-toc-modified-id="1.3.4.-Suppression-des-variables-qualitatives-non-pertinentes-2.3.4">1.3.4. Suppression des variables qualitatives non pertinentes</a></span></li><li><span><a href="#1.3.5.-Traitement-des-variables-qualitatives-pertinentes" data-toc-modified-id="1.3.5.-Traitement-des-variables-qualitatives-pertinentes-2.3.5">1.3.5. Traitement des variables qualitatives pertinentes</a></span></li></ul></li><li><span><a href="#1.4.-Traitement-des-variables-quantitatives" data-toc-modified-id="1.4.-Traitement-des-variables-quantitatives-2.4">1.4. Traitement des variables quantitatives</a></span><ul class="toc-item"><li><span><a href="#1.4.1.-Traitement-des-valeurs-impossibles-et-aberrantes" data-toc-modified-id="1.4.1.-Traitement-des-valeurs-impossibles-et-aberrantes-2.4.1">1.4.1. Traitement des valeurs impossibles et aberrantes</a></span></li><li><span><a href="#1.4.2.-Imputation-des-valeurs-manquantes-des-variables-quantitatives" data-toc-modified-id="1.4.2.-Imputation-des-valeurs-manquantes-des-variables-quantitatives-2.4.2">1.4.2. Imputation des valeurs manquantes des variables quantitatives</a></span></li><li><span><a href="#1.4.3.-Calcul-et-imputation-des-nutriscores-manquants" data-toc-modified-id="1.4.3.-Calcul-et-imputation-des-nutriscores-manquants-2.4.3">1.4.3. Calcul et imputation des nutriscores manquants</a></span></li></ul></li></ul></li><li><span><a href="#Récapitulatif-des-bases-de-données" data-toc-modified-id="Récapitulatif-des-bases-de-données-3">Récapitulatif des bases de données</a></span></li></ul></div>

# %% [markdown]
# # Contexte de l'étude

# %% [markdown]
# Ce notebook présente le nettoyage de la base de données Open Food Facts.

# %% [markdown]
# ![1200px-Open_Food_Facts_logo.svg.png](attachment:1200px-Open_Food_Facts_logo.svg.png)

# %% [markdown]
# # 1. Nettoyage de la base de données

# %% [markdown]
# ## 1.1 Importation des librairies, fonctions et données

# %% [markdown]
# Les librairies nécessaires pour l'étude sont importées dans l'environnement de travail.

# %%
import pandas as pd # le bébé panda naît avec une taille 900 fois plus petite que celle de sa mère
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt

import datetime  # Manipuler dates et heures

# Importation de mes fonctions personnalisées
import mes_packages.Optimus_Prime.description as my_desc
import mes_packages.Optimus_Prime.nettoyage as my_net
import mes_packages.Wanda_Maximoff.statiques as my_vis
import mes_packages.Mystique_Raven.special_p3 as sp3

# %% [markdown]
# ### 1.1.1. Importation du jeu de données

# %% [markdown]
# Le fichier est au format csv, la séparation est une tabulation '\t'. L'ajout de low_memory=False permet d'éviter les problèmes de mémoire lors du chargement.

# %%
import os
from dotenv import load_dotenv  # Pour récupérer les variables d'environnement
load_dotenv('var.env')  # Importation des variables d'environnement

# Récupération des variables d'environnement
chemin = os.environ['CHEMIN']

# %%
filename = "/fr.openfoodfacts.org.products.csv"

df = pd.read_csv(chemin + filename, sep='\t', low_memory=False)

# %% [markdown]
# ### 1.1.2. Description du jeu de données

# %%
""" Cette fonction affiche le nombre d'entrées et de variables dans une base de données
Entrées :
- df : dataframe
"""

# Affichage du nombre d'entrées et de variables dans la base de données
my_desc.description_df(df)
# Out:
# *Fonction by Sandy M.*
# La base de données contient 320772 lignes et 162 colonnes

# %%
print(
    f"La base de données contient {df.select_dtypes(exclude='object').shape[1]} variables quantitatives",
    f" et {df.select_dtypes(include='object').shape[1]} variables qualitatives"
)
# Out:
# La base de données contient 106 variables quantitatives  et 56 variables qualitatives

# %% [markdown]
# ## 1.2 Identification, quantification et suppression des variables (colonnes) et des produits (lignes) ayant trop de valeurs manquantes

# %% [markdown]
# ### 1.2.1 Quantification des valeurs manquantes

# %% [markdown]
# La proportion de valeurs manquantes dans la base de données est quantifiée pour l'ensemble de la base de données et suivant chaque variable.

# %%
'''
La fonction quantifier_val_manq quantifie les valeurs manquantes dans la base de données

Entrées :
- data : le dataframe

'''

# Visualisation de la part de valeurs manquantes dans notre base de données
my_desc.quantifier_val_manq(df)
# Out:
# *Fonction by Sandy M.*
# Nombre de cellules avec des données manquantes :  39608589
# Pourcentage de cellules avec des données manquantes :  76.2  %
# Nombre de lignes avec au moins une donnée manquante :  320772
# Pourcentage de lignes avec au moins une donnée manquante :  100.0  %
#                      Nombre de valeurs manquantes  Taux de valeurs manquantes
# water-hardness_100g                        320772                       100.0
# fructose_100g                              320734                       100.0
# elaidic-acid_100g                          320772                       100.0
# gondoic-acid_100g                          320758                       100.0
# mead-acid_100g                             320772                       100.0
# ...                                           ...                         ...
# created_t                                       3                         0.0
# ...

# %% [markdown]
# Il y a près de 80% de valeurs manquantes dans la base de données brute. Chaque ligne de la base de données a au moins une valeur manquante. Cela s'explique par le fait qu'il y a de nombreuses colonnes qui sont complètement vides ou qui ont un taux de remplissage très bas (inférieur à 10%).
# Il faut identifier ces variables et les supprimer de la base de données.

# %% [markdown]
# ### 1.2.2 Identification, quantification et suppression des variables ayant un taux de remplissage trop bas

# %% [markdown]
# Le graphique ci-dessous représente le taux de remplissage de chaque variable. Pour distinguer les variables à garder et celles à supprimer, un seuil de suppression est affiché sur le graphique (à un taux de remplissage de 10%).

# %%
'''
Cette fonction affiche une représentation de la quantité de cellules remplies par variable 
ainsi que la jauge qui va être appliquée pour la suppression des variables en fonction de leur remplissage

Entrées :
brut : dataframe
seuil_ remplissage : taux de valeurs manquantes (en %)

'''

# Affichage d'une représentation de la quantité de cellules remplies par variable ainsi que la jauge qui va être appliquée pour la suppression des variables en fonction de leur remplissage
my_desc.graphique_remplissage(df, 10)

# %% [markdown]
# Les variables ayant un taux de remplissage inférieur à 10% (donc un taux de valeurs manquantes supérieur à 90%) sont supprimées de la base de données.

# %%
'''
Cette fonction supprime de la base de données les variables
qui ont un taux de valeurs manquantes trop élévé et 
donne un tableau avec les variables qui n'ont pas été retenues pour la suite de l'étude

Entrées :
brut : dataframe
taux_ remplissage : taux de valeurs manquantes (en %)

Renvoie :
df_net : un dataframe sans les variables avec un taux de valeurs manquantes trop élévé

'''

# Suppression des variables qui ont un taux de valeurs manquantes trop élévé et donne un tableau avec les variables qui n'ont pas été retenues pour la suite de l'étude.
df = my_net.suppr_col_highvalmanq(df, 10)
# Out:
# La base de données contient 320772 lignes et 62 variables. Les 100 variables non-retenues sont :
# <style type="text/css">
# </style>
# <table id="T_62c5e_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Variable</th>
#       <th class="col_heading level0 col1" >Taux de valeurs manquantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_62c5e_row0_col0" class="data row0 col0" >water-hardness_100g</td>
#       <td id="T_62c5e_row0_col1" class="data row0 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62c5e_row1_col0" class="data row1 col0" >taurine_100g</td>
#       <td id="T_62c5e_row1_col1" class="data row1 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62c5e_row2_col0" class="data row2 col0" >serum-proteins_100g</td>
#       <td id="T_62c5e_row2_col1" class="data row2 col1" >100.000000</td>
#     </tr>
#     <tr>
#       <td id="T_62c5e_row3_col0" class="data row3 col0" >allergens_fr</td>
# ...

# %% [markdown]
# **Description de la base de données sans les variables non retenues**

# %%
''' Cette fonction permet de découvrir le nombre d'outliers et de valeurs manquantes de la base de données

Entrées :
data : le dataframe '''
# Description de la base de données
my_desc.data_informations(df)
# Out:
# *Fonction by Sandy M.*
# ---------------------------INFORMATION SUR LA BASE DE DONNEES------            -----------------------------------------
# Nombre de variables : 62
# Nombre d'observations : 320772
# ---------------------------VALEURS MANQUANTES-----------------------            ----------------------------------------
# Nombre de cellules avec des données manquantes :  7961987
# Pourcentage du nombre de cellules avec des données manquantes :  40.0  %
# Nombre de lignes avec au moins une donnée manquante :  320763
# Pourcentage de lignes avec au moins une donnée manquante :  100.0  %
# ---------------------------VALEURS DUPLIQUEES----------------------            -----------------------------------------
# Nombre de doublons dans la base de données :  0
# Pourcentage de doublons dans la base de données :  0.0  %
# ---------------------------VALEURS OUTLIERS------------------------            -----------------------------------------
# ...

# %% [markdown]
# ### 1.2.3 Identification et suppression des variables redondantes ou non pertinentes (d'après leur description)

# %% [markdown]
# Certaines variables sont redondantes, soit parce qu'elles ont les mêmes valeurs, soit parce qu'elles apportent la même information d'une manière différente. Il s'agit maintenant de les identifier et de garder les variables qui apportent le plus d'informations.

# %% [markdown]
# **<span style="color:green"> Les variables qualitatives </span>**

# %%
print(
    f"La base de données contient {df.select_dtypes(include='object').shape[1]} variables qualitatives"
)
# Out:
# La base de données contient 42 variables qualitatives

# %% [markdown]
# L'affichage de la proportion de valeurs uniques pour chaque variable permet de distinguer les variables pertinentes. De plus, l'affichage du nombre de valeurs manquantes permet soit d'identifier des variables redondantes, soit de faire un choix quant aux variables à garder s'il y a des similarités.

# %%
''' Cette fonction donne le nombre de valeurs manquantes par variable 
ainsi que le nombre de valeurs uniques et sa proportion pour une variable donnée

Entrées :
df : le dataframe
'''

# Affichage du nombre de valeurs manquantes et du taux de valeurs uniques par variable
my_desc.unicite(df.select_dtypes(include='object'))
# Out:
# *Fonction by Sandy M.*
#                            nb valeurs manquantes  nb de valeurs uniques  \
# variable
# code                                          23                 320750
# url                                           23                 320750
# product_name                               17762                 221348
# ingredients_text                           71810                 205521
# additives                                  71867                 196070
# created_t                                      3                 189568
# created_datetime                               9                 189569
# last_modified_t                                0                 180495
# last_modified_datetime                         0                 180495
# image_url                                 244936                  75837
# image_small_url                           244936                  75837
# ...

# %% [markdown]
# La variable "creator" n'apporte pas d'informations pertinentes. Elle est supprimée de la base de données.

# %%
df = df.drop(columns=['creator'])

# %% [markdown]
# Les variables qui contiennent des url ne sont pas pertinentes. Elles sont supprimées de la base de données. Il y a plusieurs variables qui donnent des informations sur la date de création ou de dernière modification. Dans cette étude, une seule variable de date de création de l'entrée dans la base de données est gardée.

# %%
''' Cette fonction supprime les variables qui ont un suffixe donné

Entrées :
df : le dataframe
suffixe : le suffixe (string)

Renvoie :
df : un dataframe sans les variables dont le nom contient le suffixe
'''

# Suppression des variables qui contiennent un suffixe particulier
df = my_net.drop_var_suffixe(df, 'url')
# Out:
# *Fonction by Sandy M.*

# %%
df = df.drop(
    columns=['last_modified_datetime', 'created_datetime', 'last_modified_t'])

# %% [markdown]
# Il y a des variables très similaires dans leur nombre de valeurs manquantes/uniques. Ce sont des variables qui donnent la même information.
# Seules les plus renseignées sont gardées.

# %%
df = df.rename(columns={'nutrition_grade_fr': 'nutriscore_grade'})

# %%
''' La fonction rech_col_redon recherche les colonnes redondantes
Entrées :
df : le dataframe
dico_suffixe : dictionnaire des suffixes (string) avec la condition "garder" (string)
"oui" : pour garder la variable(en gardant le suffixe) et supprimer la variable qui n'en a pas 
"non" : pour supprimer la variable dont le nom contient le suffixe

Renvoie :
variables_redondantes : la liste des variables redondantes
'''

# Recherche des colonnes redondantes
colonnes_a_supprimer = my_desc.rech_col_redon(df, {"_fr": "oui", "_tags": "non"})
colonnes_a_supprimer
# Out:
# *Fonction by Sandy M.*
# ['packaging',
#  'brands',
#  'categories',
#  'categories_fr',
#  'manufacturing_places',
#  'labels',
#  'labels_fr',
#  'countries',
#  'countries_fr',
#  'additives',
#  'additives_fr',
#  'states',
#  'states_fr',
#  'main_category_fr']

# %%
df = df.drop(columns=colonnes_a_supprimer)
del colonnes_a_supprimer
print(
    f"La base de données contient {df.select_dtypes(include='object').shape[1]} variables qualitatives"
)
# Out:
# La base de données contient 21 variables qualitatives

# %% [markdown]
# **<span style="color:green"> Les variables quantitatives </span>**

# %%
print(
    f"La base de données contient {df.select_dtypes(exclude='object').shape[1]} variables quantitatives"
)
# Out:
# La base de données contient 20 variables quantitatives

# %% [markdown]
# La première étape est de chercher les variables quantitatives ayant une forte corrélation.

# %%
'''
Cette fonction affiche les variables qui ont un taux de corrélation supérieur à une certaine valeur.

Entrées :
- df : le dataframe
- taux : le taux de corrélation maximum souhaité (float) '''
# Affichage des variables qui ont un taux de corrélation supérieur à une certaine valeur
my_desc.trouver_correlation(df, 0.9)
# Out:
# *Fonction by Sandy M.*
# salt_100g sodium_100g 1.0
# nutrition-score-fr_100g nutrition-score-uk_100g 0.99

# %% [markdown]
# Le sel contient du sodium, il est donc normal d'avoir une corrélation. Il est important de garder les deux variables. En effet, la variable "salt_100g" sera importante pour l'étude multivariée et la variable "sodium_100g" sera importante pour le calcul des nutriscores.

# %% [markdown]
# Il faut maintenant regarder si les variables "nutriscore_score" et "nutrition-score-uk_100g" sont similaires.

# %%
'''
Cette fonction donne le pourcentage de similitude de deux variables
Entrées :
df : le dataframe
'''

# Affichage du pourcentage de similitude entre deux variables
my_desc.comparaison_variables(df,
                      ["nutrition-score-fr_100g", "nutrition-score-uk_100g"])
# Out:
# *Fonction by Sandy M.*
# Les deux variables sont similaires à 96.2 %.

# %% [markdown]
# Les variables "nutriscore_score" et "nutrition-score-fr_100g" sont similaires. Seule la variable "nutrition-score-fr_100g" est conservée.

# %%
df = df.drop(columns="nutrition-score-uk_100g")
print(
    f"La base de données contient {df.select_dtypes(exclude='object').shape[1]} variables quantitatives"
)
# Out:
# La base de données contient 19 variables quantitatives

# %% [markdown]
# ### 1.2.4 Quantification et suppression des lignes ayant trop de valeurs manquantes

# %% [markdown]
# Les lignes ayant plus de 10 % de valeurs manquantes sur les variables quantitatives sont supprimées de la base de données.

# %%
'''
# Cette fonction supprime les rangées qui ont un taux de valeurs manquantes supérieur à une certaine valeur
Entrées :
- df : le dataframe
- taux : le taux de maximum de valeurs manquantes (pour les variables quantitatives)

Renvoie :
- df  : un dataframe avec les rangées supprimées
'''

# Supression des rangées qui ont un taux de valeurs manquantes supérieur à 10 % sur les variables quantitatives
df = my_net.sup_rangees_nan(df, 0.1)
# Out:
# *Fonction by Sandy M.*
# 44538 lignes de la base de données contiennent moins de 10% de variables quantitatives renseignées. Elles sont supprimées de la base de données

# %% [markdown]
# Une partie des valeurs manquantes pour les variables quantitatives a été supprimée. Celles qui restent seront remplacées par des valeurs moyennes ou des médianes lors de l'étape d'imputation.

# %%
df = df.rename(
    columns={
        'packaging_tags': 'packaging',
        'brands_tags': 'brands',
        'categories_tags': 'categories',
        'manufacturing_places_tags': 'manufacturing_places',
        'labels_tags': 'labels',
        'countries_tags': 'countries',
        'additives_tags': 'additives',
        'states_tags': 'states'
    })

print(f"La base de données contient {df.shape[0]} produits et "
      f"{df.shape[1]} variables")
# Out:
# La base de données contient 276234 produits et 40 variables

# %% [markdown]
# ## 1.3 Traitement des variables qualitatives

# %% [markdown]
# ### 1.3.1. Remplacement des valeurs manquantes des variables qualitatives

# %% [markdown]
# Pour les variables qualitatitives, les NaN sont remplacés par des unknown. En effet, un manque d'information de ces variables est une information en soit.

# %%
''' Cette fonction remplace les valeurs manquantes par une valeur pour les variables qualitatives
Entrées :
df : le dataframe
valeur : la nouvelle valeur pour les valeurs manquantes

Renvoie :
- df : un dataframe avec les valeurs manquantes remplacées par une valeur
'''

# Remplacement des valeurs manquantes par 'unknown'
df = my_net.remp_nan(df, 'unknown')
# Out:
# *Fonction by Sandy M.*

# %% [markdown]
# ### 1.3.2. Quantification et suppression des produits impossible à identifier

# %% [markdown]
# Certains produits sont impossible à identifier. Ils n'ont ni "product name", ni "brand-tags", ni "category". Ils sont supprimés de la base de données.

# %%
''' Cette fonction supprime les lignes qui ne contiennent que des "unknown' sur certaines variables et donne le nombre de lignes qui ont été supprimées
Entrées :
df : le dataframe
valeur : la valeur qui ne permet pas d'identifier l'entrée

Renvoie :
df : un dataframe sans les entrées impossibles à identifier

'''

# La fonction suppr_inconnus supprime les lignes qui ne contiennent que des "unknown' sur certaines variables et donne le nombre de lignes qui ont été supprimées
df = sp3.suppr_inconnus(df, "unknown")
# Out:
# *Fonction by Sandy M.*
# Il y a  2863  produits impossibles à identifier. Ils sont supprimés             de la base de données.

# %% [markdown]
# ### 1.3.3. Quantification et suppression des lignes dupliquées

# %% [markdown]
# Dans cette étude, un doublon est une ligne qui a le même nom de produit, la même marque et la même énergie en kcal. Ces lignes sont quantifiées et supprimées de la base de données.

# %%
'''
# Cette fonction supprime les entrées ayant les mêmes valeurs sur un ensemble de variables
Entrées :
df : le dataframe
liste_variables : la liste des variables 
Renvoie :
df : un dataframe sans les doublons
'''

# Supression des entrées ayant les mêmes valeurs sur un ensemble de variables
df = my_net.supp_dupli(df, ['product_name', 'brands', 'energy_100g'])
# Out:
# *Fonction by Sandy M.*
# Il y a  11936  lignes dupliquées dans la base de données. Elles sont supprimées de la base de données

# %% [markdown]
# ### 1.3.4. Suppression des variables qualitatives non pertinentes

# %% [markdown]
# **<span style="color:orange"> La variable "states" </span>**

# %%
df['states'].head(5)
# Out:
# 1    en:to-be-completed,en:nutrition-facts-complete...
# 2    en:to-be-completed,en:nutrition-facts-complete...
# 3    en:to-be-completed,en:nutrition-facts-complete...
# 4    en:to-be-completed,en:nutrition-facts-complete...
# 5    en:to-be-completed,en:nutrition-facts-complete...
# Name: states, dtype: object

# %% [markdown]
# La variable "states" n'apporte pas d'information intéressante. Elle est supprimée de la base de données.

# %%
df = df.drop(columns=['states'])

# %% [markdown]
# **<span style="color:orange"> La variable "categories" </span>**

# %%
df['categories'].value_counts(ascending=False)
# Out:
# unknown                                                                                                                                                                                                   186517
# en:sugary-snacks,en:biscuits-and-cakes,en:biscuits                                                                                                                                                           762
# en:sugary-snacks,en:chocolates,en:dark-chocolates                                                                                                                                                            571
# en:sugary-snacks,en:confectioneries,en:candies                                                                                                                                                               476
# ...

# %% [markdown]
# La variable "categories" apporte trop d'informations par ligne. De plus, elle est résumée dans la variable "main_category". Elle est supprimée de la base de données.

# %%
df = df.drop(columns=['categories'])

# %% [markdown]
# **<span style="color:orange"> La variable "stores" </span>**

# %% [markdown]
# La variable "stores" n'est pas pertinente pour l'étude. Elle n'a pas d'influence sur la qualité d'un produit. Elle est supprimée de la base de données.

# %%
df = df.drop(columns=['stores'])

# %% [markdown]
# ### 1.3.5. Traitement des variables qualitatives pertinentes

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261435 entries, 1 to 320771
# Data columns (total 18 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   code                  261435 non-null  object
#  1   created_t             261435 non-null  object
#  2   product_name          261435 non-null  object
#  3   generic_name          261435 non-null  object
#  4   quantity              261435 non-null  object
#  5   packaging             261435 non-null  object
#  6   brands                261435 non-null  object
#  7   manufacturing_places  261435 non-null  object
#  8   labels                261435 non-null  object
#  9   purchase_places       261435 non-null  object
#  10  countries             261435 non-null  object
#  11  ingredients_text      261435 non-null  object
#  12  serving_size          261435 non-null  object
#  13  additives             261435 non-null  object
# ...

# %% [markdown]
# **<span style="color:orange"> La variable "product_name" </span>**

# %%
df['product_name'].value_counts()
# Out:
# unknown                                                              738
# Ice Cream                                                            334
# Extra Virgin Olive Oil                                               202
# Potato Chips                                                         175
# Premium Ice Cream                                                    158
#                                                                     ...
# Filet de haddock                                                       1
# Boneless Beef Shoulder Cross-Rib Roast                                 1
# Beef Flanken Ribs                                                      1
# Beef London Broil                                                      1
# Mint Melange Tea A Blend Of Peppermint, Lemon Grass And Spearmint      1
# Name: product_name, Length: 197722, dtype: int64

# %% [markdown]
# La variable "product_name" sert à l'identification du produit.
# Néanmoins, il faudra se rappeler que pour l'analyse multivariée elle peut créer des problèmes à cause de son grand nombre de valeurs différentes.

# %% [markdown]
# **<span style="color:orange"> La variable "quantity" </span>**

# %%
df['quantity'].value_counts()
# Out:
# unknown                                 180834
# 500 g                                     3924
# 200 g                                     3549
# 250 g                                     3382
# 100 g                                     2648
#                                          ...
# 351 g (305 g + 46 g) - 2/3 personnes         1
# 308 g (dont 10% gratuit)                     1
# 330 g (300 g + 30 g gratuit)                 1
# 250 g (2-3 Pers.)                            1
# 250 g (10 pièces)                            1
# Name: quantity, Length: 11120, dtype: int64

# %% [markdown]
# La variable "quantity" n'est pas pertinente au niveau des valeurs mais ces unités peuvent indiquer si le produit est solide, liquide (ou "autre").

# %%
'''
# Cette fonction construit une colonne solide/liquide/unknown à partir d'une colonne indiquant une quantité
Entrées :
df : le dataframe
var : la variable qui indique une quantité
col : le nom de la variable qui va indiquer si le produit est 'solide', 'liquide' ou 'unknown'

'''
# Construction d'une colonne solide/liquide/unknown à partir d'une colonne indiquant une quantité
df = sp3.quantity_to_s_or_l(df, 'quantity', 'solide_ou_liquide1')
df = df.drop(columns=['quantity'])
# Out:
# *Fonction by Sandy M.*

# %% [markdown]
# La variable "quantity" peut être supprimée du fait que la variable "'solide_ou_liquide1" donne une information plus pertinente.

# %% [markdown]
# **<span style="color:orange"> La variable "packaging" </span>**

# %%
df['packaging'].value_counts()
# Out:
# unknown                                                                            190707
# sachet,plastique                                                                     3665
# carton                                                                               2702
# plastique                                                                            2609
# barquette,plastique                                                                  1994
#                                                                                     ...
# carton,sachet-papier-alu                                                                1
# frais,pot,verre,opercule,aluminium,etui,carton,frais                                    1
# bocal-verre,opercule-metal,etiquette-papier,bocal-verre,boite-metal,conserve            1
# en-bouteille-plastique-et-son-bouchon-a-recycler,fr-pensez-au-tri,fr-point-vert         1
# ...

# %% [markdown]
# La variable "packaging" contient des informations sur le packaging des produits dans plusieurs langues avec plusieurs façons d'écrire le même emballage.
# Il s'agit maintenant de créer une variable "packaging" qui regroupe plusieurs façons de décrire un emballage sous la même modalité.

# %%
'''
Cette fonction détecte des mots issus d'un dictionnaire pour les changer, il remplace la valeur par 'other' si le mot n'est pas contenu dans le dictionnaire
Entrées :
entrees = df[variable]
dictionary = dictionnaire dont les clés sont les listes des valeurs acceptables pour la variable
defaut = remplaçant de la valeur si celle-ci ne se trouve pas dans les clés du dictionnaire

Renvoie :
result : liste des nouvelles valeurs    
'''
# Détection des mots issus d'un dictionnaire pour les changer, il remplace la valeur par 'other' si le mot n'est pas contenu dans le dictionnaire
df['packaging'] = my_desc.detect_words_other(df['packaging'], sp3.Dico_packaging_tags,
                                     'autre')
df['packaging'] = df['packaging'].str.capitalize()
# Out:
# *Fonction by Sandy M.*

# %%
df['packaging'].value_counts()
# Out:
# Unknown                190707
# Plastique               16953
# Carton                  16755
# Sachet,plastique         9990
# Autre                    8929
# Barquette,plastique      3729
# Verre                    3370
# Conserve                 3342
# Bocal,verre              2680
# Bouteille,verre          2174
# Brique,carton            1657
# Bouteille                 906
# Papier                    243
# Name: packaging, dtype: int64

# %% [markdown]
# Les emballages sont ensuite regroupés par matière dans une nouvelle variable "packaging_matiere".

# %%
Dico_packaging_matiere = {
    'verre': 'verre',
    'plastique': 'plastique',
    'carton': 'carton',
    'conserve': 'metal',
    'papier': 'papier',
    'unknown': 'unknown',
}

# %%
# Regroupement des packaging par matière
df['packaging_matiere'] = my_desc.detect_words_other(df['packaging'].str.lower(),
                                             Dico_packaging_matiere, 'autre')
df['packaging_matiere'] = df['packaging_matiere'].str.capitalize()
# Out:
# *Fonction by Sandy M.*

# %%
df['packaging_matiere'].value_counts()
# Out:
# Unknown      190707
# Plastique     30672
# Carton        18412
# Autre          9835
# Verre          8224
# Metal          3342
# Papier          243
# Name: packaging_matiere, dtype: int64

# %% [markdown]
# Il n'est pas nécessaire de garder les variables "packaging" et "packaging_matiere" dans la base de données. En effet, ce qui est intéressant ce sont les proportions de chacune de leurs modalités. Pour résumer celà, deux petites bases de données réunissant les proportions des modalités de chacune de ces variables sont créées.

# %%
''' Cette fonction crée une petite base de données en comptant le nombre de modalités par variable
Entrées :
df : le dataframe
col : la variable d'origine
var1 : la variable de destination
var2 : la variable value_counts() de la variable col
reindexer : string si oui : opère une réindexation
liste_reindex : liste pour effectuer la reindexation

Renvoie :
data : une petite base de données correspondant aux modalités et leur nombre d'apparition au sein de la variable
'''

# La fonction mini_bdd permet de construire une base de données à partir d'un value_counts()
data_packaging = my_desc.mini_bdd(df,
                          'packaging',
                          "Emballage",
                          "Nombre",
                          reindexer='oui',
                          liste_reindex=[
                              'Unknown', 'Plastique', 'Sachet,plastique',
                              'Barquette,plastique', 'Autre', 'Bouteille',
                              'Carton', 'Brique,carton', 'Verre',
                              'Bocal,verre', 'Bouteille,verre', 'Conserve',
                              'Papier'
                          ])
data_packaging
# Out:
# *Fonction by Sandy M.*
#               Emballage  Nombre
# 0               Unknown  190707
# 1             Plastique   16953
# 2      Sachet,plastique    9990
# 3   Barquette,plastique    3729
# 4                 Autre    8929
# 5             Bouteille     906
# 6                Carton   16755
# 7         Brique,carton    1657
# 8                 Verre    3370
# 9           Bocal,verre    2680
# 10      Bouteille,verre    2174
# 11             Conserve    3342
# 12               Papier     243

# %%
# La fonction mini_bdd permet de construire une base de données à partir d'un value_counts()
data_matiere = my_desc.mini_bdd(df, 'packaging_matiere', "Matière Emballage", "Nombre")
data_matiere
# Out:
# *Fonction by Sandy M.*
#   Matière Emballage  Nombre
# 0           Unknown  190707
# 1         Plastique   30672
# 2            Carton   18412
# 3             Autre    9835
# 4             Verre    8224
# 5             Metal    3342
# 6            Papier     243

# %%
df = df.drop(columns=['packaging', 'packaging_matiere'])

# %% [markdown]
# **<span style="color:orange"> La variable "brands" </span>**

# %%
df['brands'].value_counts(ascending=False)
# Out:
# unknown                  3799
# carrefour                2712
# auchan                   2047
# u                        1825
# meijer                   1778
#                          ...
# pickled-pink                1
# simply-snackin              1
# magnoodles                  1
# berry-s                     1
# sans-marque,d-lambert       1
# Name: brands, Length: 45129, dtype: int64

# %% [markdown]
# La variable "brands" peut aider à combler des valeurs manquantes pour des variables quantitatives. Elle reste dans la base de données jusqu'à la fin de l'étape d'imputation.

# %% [markdown]
# **<span style="color:orange"> La variable "labels" </span>**

# %%
df['labels'].value_counts()
# Out:
# unknown                                                                                 218000
# en:organic,en:eu-organic,fr:ab-agriculture-biologique                                     5036
# en:green-dot                                                                              2298
# en:vegetarian,en:vegan                                                                    1533
# en:green-dot,fr:eco-emballages                                                             816
#                                                                                          ...
# fr:viande-francaise,en:green-dot,en:produced-in-bretagne,fr:viande-porcine-francaise         1
# fr:sans-cartilage,fr:sans-couenne                                                            1
# en:sans-colorants,en:sans-conservateurs                                                      1
# en:incorrect-data-on-label,en:no-colorings,en:no-preservatives,en:green-dot                  1
# ...

# %% [markdown]
# La variable "labels" a beaucoup de valeurs différentes. Il faut regrouper les informations sous des labels principaux.

# %%
Dico_labels = {
    'unknown': 'unknown',
    'organic': 'bio',
    'gluten-free': 'sans gluten',
    'no-gluten': 'sans gluten',
    'green-dot': 'eco-emballage',
    'vegetarian': 'vegetarien',
    'no-preservatives': 'sans conservateur',
    'no-coloring': 'sans colorant',
    'sugar': 'sans sucre ajouté',
    'made-in-france': 'fabriqué en France'
}

# %%
# Regroupement des packaging par matière
df['labels'] = my_desc.detect_words_other(df['labels'].str.lower(), Dico_labels,
                                  'autre')
df['labels'] = df['labels'].str.capitalize()
# Out:
# *Fonction by Sandy M.*

# %%
df['labels'].value_counts()
# Out:
# Unknown               218000
# Autre                  13458
# Bio                    10099
# Eco-emballage           7096
# Vegetarien              4686
# Sans colorant           1884
# Fabriqué en france      1865
# Sans conservateur       1484
# Sans gluten             1456
# Sans sucre ajouté       1407
# Name: labels, dtype: int64

# %% [markdown]
# **<span style="color:orange"> La variable "countries" </span>**

# %% [markdown]
# La variable "countries" est transformée en une variable qui contient les 25 pays les plus représentés et qui regroupe les autres pays dans une valeur 'Autre'.

# %%
df['countries'] = df['countries'].str.split(',').str[0]
df['countries'] = df['countries'].str[3:]

# %%
df['countries'] = my_desc.detect_words_other(df['countries'], sp3.Dico_countries, 'Autre')
# Out:
# *Fonction by Sandy M.*

# %%
df['countries'].value_counts()
# Out:
# Etats-Unis     161736
# France          72123
# Suisse           9162
# Allemagne        5512
# Espagne          3768
# Royaume-Uni      2325
# Belgique         1477
# Autre            1397
# Russie            870
# Australie         761
# Italie            498
# Portugal          492
# Canada            268
# Pays-Bas          264
# Autriche          187
# Unknown            94
# Roumanie           91
# Irlande            88
# Pologne            81
# Suède              64
# Thaïlande          39
# Norvège            39
# Luxembourg         35
# Mexique            32
# Argentine          15
# Finlande           13
# Maroc               4
# Name: countries, dtype: int64

# %% [markdown]
# **<span style="color:orange"> La variable ingredients_text </span>**

# %%
df['ingredients_text'].value_counts()
# Out:
# unknown                                                                                                                                                                                                       25813
# Almonds.                                                                                                                                                                                                        202
# Semolina (wheat), durum flour (wheat), niacin, ferrous sulfate (iron), thiamin mononitrate, riboflavin, folic acid.                                                                                             176
# Carbonated water, natural flavor.                                                                                                                                                                               175
# ...

# %% [markdown]
# La variable "ingredients_text" ne donne pas d'information exploitable facilement ligne par ligne, cependant il est possible de rechercher les ingrédients les plus courants utilisés pour la fabrication des aliments de la base de données.

# %%
''' La fonction most_common_words permet de chercher les mots les plus représentés dans une colonne
Entrées :
sep : caractère de séparation des éléments de la liste
labels : liste des valeurs
nombre : "top nombre" des mots les plus représentés

Renvoie :
liste : la liste des mots les plus représentés
compte : le nombre d'apparitions de chaque mot de la liste
'''

# Récupération des mots les plus représentés au sein des ingrédients des produits
ingredients, nombre_ingr = my_desc.most_common_words(",",
                                             df['ingredients_text'].values, 32)
compte_ingredients = pd.DataFrame(data={
    'Nom_Ingredient': ingredients,
    'Nombre': nombre_ingr
})
compte_ingredients.head(5)
# Out:
# *Fonction by Sandy M.*
#   Nom_Ingredient  Nombre
# 0           salt   78168
# 1          sugar   49445
# 2          water   45610
# 3            sel   28325
# 4        unknown   25813

# %%
''' Cette fonction remplace les erreurs de frappes et uniformise la langue de la liste d'ingrédient
Entrées 
- compte_ingrédients : le dataframe mots / décompte

Renvoie :
- compte_ingrédients : le dataframe bien orthographié et traduit
'''

# transformation du décompte des ingrédients
compte_ingredients = sp3.transf_ingredients(compte_ingredients)
compte_ingredients.head(5)
# Out:
# *Fonction by Sandy M.*
#   Nom_Ingredient  Nombre
# 0           salt  124103
# 1          sugar   78596
# 2          water   72120
# 3        unknown   25813
# 4    citric acid   22811

# %%
'''
Cette fonction affiche un tableau qui donne les effectifs, les fréquences et les fréquences cumulées des entrées par modalités d'une variable
Entrées :
- df : le dataframe
- col_nom : la variable qui contient le nom des entités
- col_num : la variable qui renvoie le nombre d'entités
'''

# Tableau des effectifs et des fréquences
my_desc.tableau_effectif_frequence(compte_ingredients, 'Nom_Ingredient', 'Nombre')
# Out:
# *Fonction by Sandy M.*
# <style type="text/css">
# </style>
# <table id="T_23b01_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Nom_Ingredient</th>
#       <th class="col_heading level0 col1" >n</th>
#       <th class="col_heading level0 col2" >f</th>
#       <th class="col_heading level0 col3" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_23b01_row0_col0" class="data row0 col0" >salt</td>
#       <td id="T_23b01_row0_col1" class="data row0 col1" >124103</td>
#       <td id="T_23b01_row0_col2" class="data row0 col2" >0.231553</td>
#       <td id="T_23b01_row0_col3" class="data row0 col3" >0.231553</td>
#     </tr>
#     <tr>
#       <td id="T_23b01_row1_col0" class="data row1 col0" >sugar</td>
#       <td id="T_23b01_row1_col1" class="data row1 col1" >78596</td>
#       <td id="T_23b01_row1_col2" class="data row1 col2" >0.146645</td>
#       <td id="T_23b01_row1_col3" class="data row1 col3" >0.378198</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# La variable "ingredients_text" n'apporte pas d'information intéressante. Elle est supprimée de la base de données.
# Par contre, la nouvelle base de données qui donne les ingrédients présents dans la totalité de la base de données est conservée.

# %%
df = df.drop(columns=['ingredients_text'])

# %% [markdown]
# **<span style="color:orange"> La variable serving_size </span>**

# %%
df['serving_size'].value_counts()
# Out:
# unknown                                  62852
# 240 ml (8 fl oz)                          5083
# 28 g (1 oz)                               4973
# 28 g (1 ONZ)                              3563
# 30 g (2 Tbsp)                             2733
#                                          ...
# 30 g (2 CRACKERS)                            1
# 30 g (1 1/2 CRACKER)                         1
# 73 g (2.5 oz)                                1
# 32 g (1/4 tasse) - 32 g (1/4 cop dry)        1
# 25 g (bun)                                   1
# Name: serving_size, Length: 25060, dtype: int64

# %%
# La fonction quantity_to_s_or_l construit une colonne solide/liquide/unknown à partir d'une colonne indiquant une quantité
df = sp3.quantity_to_s_or_l(df, 'serving_size', 'solide_ou_liquide2')
# Out:
# *Fonction by Sandy M.*

# %% [markdown]
# La variable "serving_size" est pertinente à la fois au niveau de ses valeurs et de ses unités qui peuvent indiquer si le produit est solide, liquide (ou "autre").

# %%
df['solide_ou_liquide2'].value_counts()
# Out:
# solide     172225
# unknown     63163
# liquide     26047
# Name: solide_ou_liquide2, dtype: int64

# %% [markdown]
# Pour obtenir une variable plus complète, la variable "solide_ou_liquide2" est fusionnée avec la variable "solide_ou_liquide1".

# %%
''' Cette fonction fusionne deux colonnes pour en créer une nouvelle.
Entrées :
df : le dataframe
col1 : la premiere variable à fusionner
col2 : la deuxieme variable à fusionner
col3 : le nom de la nouvelle variable
unknown : la valeur qui remplace les nan

Renvoie :
df : le dataframe avec la nouvelle variable
'''
df = my_desc.df_fusion(df, 'solide_ou_liquide1', 'solide_ou_liquide2',
               'solide_ou_liquide', 'unknown')
# Out:
# *Fonction by Sandy M.*

# %% [markdown]
# Seule la variable complétée est conservée.

# %% [markdown]
# Il est possible d'extraire les informations numériques de la variable "serving_size". Une variable "serving_size_g_ou_ml" qui donne la quantité pour la portion (en ml pour les liquide, en g pour les solides) est créée.

# %%
df['serving_size_g_ou_ml'] = df['serving_size'].str.extract('(\d?\d?\d)',
                                                            expand=True)
df['serving_size_g_ou_ml'] = df['serving_size_g_ou_ml'].astype(float,
                                                               errors='raise')

# %% [markdown]
# Attention, les unknown ont été convertis en NaN. Cette variable quantitative devra être imputée dans la suite de cette étude.

# %% [markdown]
# La variable 'serving_size' a été traitée, elle peut être supprimée.

# %%
df = df.drop(columns=['serving_size'])

# %% [markdown]
# **<span style="color:orange"> La variable additives </span>**

# %%
df['additives'] = df['additives'].str[3:]
df['additives'] = df['additives'].replace('nown', 'unknown')
df['additives'].value_counts()
# Out:
# unknown                                                  114971
# e322                                                       7821
# e375,en:e101                                               7357
# e330                                                       7277
# e300                                                       2857
#                                                           ...
# e330,en:e327,en:e418,en:e300,en:e160                          1
# e330,en:e331,en:e466,en:e412                                  1
# e296,en:e330,en:e300,en:e307a,en:e133,en:e171                 1
# e508,en:e339iii,en:e316                                       1
# e330,en:e951,en:e150a,en:e950,en:e552,en:e102,en:e129         1
# Name: additives, Length: 40617, dtype: int64

# %% [markdown]
# La variable "additives" ne donne pas d'information exploitable facilement ligne par ligne. Néanmoins, il est possible de rechercher les additifs les plus courants utilisés pour les aliments de la base de données.

# %%
# La fonction most_common_words permet de chercher les mots les plus représentés dans une colonne
additifs, nombre_additifs = my_desc.most_common_words(",en:", df['additives'].values,
                                              25)
compte_additifs = pd.DataFrame(data={
    'Nom_Additif': additifs,
    'Nombre': nombre_additifs
})
compte_additifs['Nom_Additif'] = compte_additifs['Nom_Additif'].str.capitalize(
)
# Out:
# *Fonction by Sandy M.*

# %%
# La fonction tableau_effectif_frequence_2col affiche un tableau qui donne les effectifs, les fréquences et les fréquences cumulées des entrées par modalités d'une variable
my_desc.tableau_effectif_frequence(compte_additifs, 'Nom_Additif', 'Nombre')
# Out:
# *Fonction by Sandy M.*
# <style type="text/css">
# </style>
# <table id="T_02477_">
#   <thead>
#     <tr>
#       <th class="col_heading level0 col0" >Nom_Additif</th>
#       <th class="col_heading level0 col1" >n</th>
#       <th class="col_heading level0 col2" >f</th>
#       <th class="col_heading level0 col3" >F</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <td id="T_02477_row0_col0" class="data row0 col0" >Unknown</td>
#       <td id="T_02477_row0_col1" class="data row0 col1" >114971</td>
#       <td id="T_02477_row0_col2" class="data row0 col2" >0.303494</td>
#       <td id="T_02477_row0_col3" class="data row0 col3" >0.303494</td>
#     </tr>
#     <tr>
#       <td id="T_02477_row1_col0" class="data row1 col0" >E330</td>
#       <td id="T_02477_row1_col1" class="data row1 col1" >42286</td>
#       <td id="T_02477_row1_col2" class="data row1 col2" >0.111624</td>
#       <td id="T_02477_row1_col3" class="data row1 col3" >0.415118</td>
#     </tr>
#     <tr>
# ...

# %% [markdown]
# La variable "additives" est résumée dans additives_n, elle peut être supprimée de la base de données.
# Par contre, la nouvelle base de données qui donne le nombre des 25 additifs les plus présents dans la totalité de la base de données est conservée.

# %%
df = df.drop(columns=['additives'])

# %% [markdown]
# **<span style="color:orange"> La variable pnns_groups_1 </span>**

# %%
df['pnns_groups_1'].value_counts()
# Out:
# unknown                    198963
# Sugary snacks               11269
# Milk and dairy products      8073
# Cereals and potatoes         7826
# Beverages                    7742
# Fish Meat Eggs               7243
# Composite foods              6430
# Fruits and vegetables        5355
# Fat and sauces               4556
# Salty snacks                 2591
# fruits-and-vegetables         915
# sugary-snacks                 455
# cereals-and-potatoes           16
# salty-snacks                    1
# Name: pnns_groups_1, dtype: int64

# %% [markdown]
# Certaines modalités sont identiques mais écrites d'une façon différente. Elles sont rassemblées sous la même modalité.

# %%
df['pnns_groups_1'].replace(
    {
        'sugary-snacks': 'Sugary snacks',
        'fruits-and-vegetables': 'Fruits and vegetables',
        'cereals-and-potatoes': 'Cereals and potatoes',
        'salty-snacks': 'Salty snacks'
    },
    inplace=True)

# %% [markdown]
# **<span style="color:orange"> La variable pnns_groups_2 </span>**

# %% [markdown]
# Il y a des doublons du fait que certaines modalités ont une majuscule. Il suffit de mettre une majuscule au début de chaque modalité.

# %%
df['pnns_groups_2'] = df['pnns_groups_2'].str.capitalize()
df['pnns_groups_2'].value_counts()
# Out:
# Unknown                             196975
# One-dish meals                        5289
# Biscuits and cakes                    4285
# Sweets                                4114
# Cereals                               3839
# Cheese                                3671
# Non-sugared beverages                 3451
# Vegetables                            3425
# Dressings and sauces                  3146
# Processed meat                        2991
# Milk and yogurt                       2969
# Chocolate products                    2870
# Fish and seafood                      2363
# Appetizers                            1942
# Sweetened beverages                   1932
# Alcoholic beverages                   1921
# Fruits                                1912
# Fruit juices                          1764
# Bread                                 1721
# Meat                                  1522
# Fats                                  1410
# Breakfast cereals                     1296
# ...

# %% [markdown]
# Une petite base de données donnant le nombre de produits par modalité est créée.

# %%
# Création d'une petite base de données avec les modalités de la variable 'Groupement 02' et leur effectif
data_pnns = my_desc.mini_bdd(df, 'pnns_groups_2', "Groupement 02", "Nombre")
data_pnns
# Out:
# *Fonction by Sandy M.*
#                        Groupement 02  Nombre
# 0                            Unknown  196975
# 1                     One-dish meals    5289
# 2                 Biscuits and cakes    4285
# 3                             Sweets    4114
# 4                            Cereals    3839
# 5                             Cheese    3671
# 6              Non-sugared beverages    3451
# 7                         Vegetables    3425
# 8               Dressings and sauces    3146
# 9                     Processed meat    2991
# 10                   Milk and yogurt    2969
# 11                Chocolate products    2870
# 12                  Fish and seafood    2363
# 13                        Appetizers    1942
# 14               Sweetened beverages    1932
# 15               Alcoholic beverages    1921
# 16                            Fruits    1912
# 17                      Fruit juices    1764
# 18                             Bread    1721
# ...

# %% [markdown]
# Une colonne pour la variable "pnns_groups_1" est créée au sein de la petite base de données.

# %%
''' Cette fonction rajoute une variable avec un groupement pnns1 qui correspondant au groupement pnns2
Entrées :
data_pnns : le dataframe qui contient la variable 'Groupement 02'
Renvoie :
data_pnns : le dataframe avec la variable 'Groupement 01'
'''

# Ajout d'une variable 'Groupement 01'
data_pnns = sp3.colonne_pnns(data_pnns)
data_pnns
# Out:
# *Fonction by Sandy M.*
#                        Groupement 02  Nombre            Groupement 01
# 0                            Unknown  196975                    Autre
# 1                     One-dish meals    5289          Composite foods
# 2                 Biscuits and cakes    4285            Sugary snacks
# 3                             Sweets    4114            Sugary snacks
# 4                            Cereals    3839     Cereals and potatoes
# 5                             Cheese    3671  Milk and dairy products
# 6              Non-sugared beverages    3451                Beverages
# 7                         Vegetables    3425    Fruits and vegetables
# 8               Dressings and sauces    3146           Fat and sauces
# 9                     Processed meat    2991           Fish Meat Eggs
# 10                   Milk and yogurt    2969  Milk and dairy products
# 11                Chocolate products    2870            Sugary snacks
# ...

# %% [markdown]
# **<span style="color:orange"> La variable main_category </span>**

# %%
df['main_category'] = df['main_category'].str[3:]
df['main_category'] = df['main_category'].replace('nown', 'unknown')
df['main_category'].value_counts()
# Out:
# unknown                            186517
# beverages                            4644
# groceries                            2579
# chocolates                           2568
# plant-based-foods-and-beverages      2549
#                                     ...
# biscuits-pur-beurre                     1
# filets-de-cabillaud-panes               1
# quiches-lorraines                       1
# entrees-surgelees                       1
# attieke                                 1
# Name: main_category, Length: 2739, dtype: int64

# %% [markdown]
# Cette variable peut aider à combler des valeurs manquantes pour des variables quantitatives. Elle sera conservée jusqu'à la fin du nettoyage de la base de données

# %% [markdown]
# **<span style="color:orange"> La variable nutriscore_grade </span>**

# %%
df['nutriscore_grade'].value_counts()
# Out:
# d          59641
# unknown    51043
# c          43463
# e          40800
# a          33978
# b          32510
# Name: nutriscore_grade, dtype: int64

# %% [markdown]
# Cette variable a une grande quantité de valeurs manquantes. Néanmoins les valeurs manquantes pourront être estimées grâce aux autres variables.

# %%
df.select_dtypes(include='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261435 entries, 1 to 320771
# Data columns (total 14 columns):
#  #   Column                Non-Null Count   Dtype
# ---  ------                --------------   -----
#  0   code                  261435 non-null  object
#  1   created_t             261435 non-null  object
#  2   product_name          261435 non-null  object
#  3   generic_name          261435 non-null  object
#  4   brands                261435 non-null  object
#  5   manufacturing_places  261435 non-null  object
#  6   labels                261435 non-null  object
#  7   purchase_places       261435 non-null  object
#  8   countries             261435 non-null  object
#  9   nutriscore_grade      261435 non-null  object
#  10  pnns_groups_1         261435 non-null  object
#  11  pnns_groups_2         261435 non-null  object
#  12  main_category         261435 non-null  object
#  13  solide_ou_liquide     261435 non-null  object
# dtypes: object(14)
# ...

# %% [markdown]
# ## 1.4. Traitement des variables quantitatives

# %% [markdown]
# ### 1.4.1. Traitement des valeurs impossibles et aberrantes

# %%
df.select_dtypes(exclude='object').info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 261435 entries, 1 to 320771
# Data columns (total 20 columns):
#  #   Column                                   Non-Null Count   Dtype
# ---  ------                                   --------------   -----
#  0   additives_n                              235621 non-null  float64
#  1   ingredients_from_palm_oil_n              235621 non-null  float64
#  2   ingredients_that_may_be_from_palm_oil_n  235621 non-null  float64
#  3   energy_100g                              246919 non-null  float64
#  4   fat_100g                                 229837 non-null  float64
#  5   saturated-fat_100g                       217942 non-null  float64
#  6   trans-fat_100g                           135343 non-null  float64
#  7   cholesterol_100g                         136232 non-null  float64
#  8   carbohydrates_100g                       229527 non-null  float64
#  9   sugars_100g                              232139 non-null  float64
# ...

# %% [markdown]
# **<span style="color:orange"> La variable created_t </span>**

# %% [markdown]
# La variable "created_t" permet de créer une nouvelle variable avec seulement l'année de création pour valeur. Cela permettra de faire des analyses "par année" dans la suite de l'étude.

# %%
df = df[(df['created_t'] != "Villecresnes,Villeurbanne,France")]
df = df[(df['created_t'] != '0')]
df['date'] = pd.to_datetime(df['created_t'], unit='s')
df['year'] = pd.DatetimeIndex(df['date']).year
df = df.drop(columns=['date'])

# %% [markdown]
# **Suppression des valeurs impossibles d'après la définition des variables**

# %% [markdown]
# **<span style="color:orange"> Les variables energy_100g et energy-kcal_100g </span>**

# %% [markdown]
# La variable "energy_100g" est en kJ et la variable "energy-kcal_100g" est en kcal. La conversion se fait avec le rapport 1 kJ = 0.2388 (ou 1 kcal = 4.1860 kJ).
# Il est important de garder la variable en kJ car elle servira au calcul du nutriscore.

# %% [markdown]
# Bien que ces deux variables n'aient pas de valeurs manquantes, il est important de regarder si elles n'ont pas de valeurs impossibles. Par exemple, elles ne peuvent ni être négatives, ni avoir une valeur supérieure à 1000 pour "energy-kcal_100g" et à 4000 pour "energy_100g".

# %%
""" Cette fonction remplace les entrées strictement supérieures  ou inférieures à un seuil par des nan
Entrées :
df : le dataframe
variable : la variable d'intérêt
value : la valeur seuil
limite : si le seuil est une limite basse ou une limite haute (string)

Renvoie :
df : le dataframe
"""

# Remplatement des entrées supérieures à une certaine valeur par NaN
df = my_net.nan_seuil(df, 'energy_100g', 5000, "haute")

# %%
# Remplacement des valeurs négatives par des NaN
df = my_net.nan_seuil(df, 'energy_100g', 0, "basse")

print('La variable energy_100g compte désormais',
      df['energy_100g'].isnull().sum(), ' valeurs manquantes')
# Out:
# La variable energy_100g compte désormais 14597  valeurs manquantes

# %%
df['energy_100g'].hist(bins=100)
plt.title("Répartition de l'énergie pour 100g en kJ dans la base de données")
plt.xlabel("Energie pour 100g (en kJ)")
plt.ylabel("Nombre d'entrées")
plt.show()

# %% [markdown]
# Sur cet histogramme, il est possible de voir qu'il y a beaucoup de valeurs à zero. Elles ne peuvent pas être supprimées car il n'est pas possible de savoir si c'est une erreur ou si c'est un aliment à zero calorie (comme l'eau ou les condiments par exemple). Ceci peut être vérifié en regardant une base de données avec uniquement les entrées concernant energy_100g = 0.

# %%
df.loc[df['energy_100g'] == 0].sample(5)
# Out:
#                  code   created_t                           product_name  \
# 173696  0897865001002  1489143403  Herbal Water, Lemongrass Mint Vanilla
# 32995   0036800254220  1489143528                100% Lemon Juice, Lemon
# 88113   0075130481425  1489055382                           Iodized Salt
# 182305       22113746  1433398896                    Jodsalz mit Fluorid
# 108605  0094922518194  1489076435      Tekola, Pure Ceylon Tea Black Tea
#
#                                        generic_name  \
# 173696                                      unknown
# 32995                                       unknown
# 88113                                       unknown
# 182305  Jodiertes Speisesalz mit Zusatz von Fluorid
# 108605                                      unknown
#
#                                 brands manufacturing_places   labels  \
# 173696            ayala-s-herbal-water              unknown  Unknown
# 32995   food-club,topco-associates-inc              unknown  Unknown
# ...

# %% [markdown]
# **<span style="color:orange"> Les variables fat_100g , saturated-fat_100g et trans-fat_100g </span>**

# %% [markdown]
# Les variables  "fat_100g" , "saturated-fat_100g" et "trans-fat_100g" ne doivent jamais dépasser 100g, ni être négatives.
# De plus, la somme de "saturated-fat_100g" et "trans-fat_100g" ne doit pas dépasser la valeur de "fat_100g".

# %%
columns = ['fat_100g', 'saturated-fat_100g', 'trans-fat_100g']
for column in columns:
    df = my_net.nan_seuil(df, column, 100, "haute")
    df = my_net.nan_seuil(df, column, 0, "basse")

df.loc[df['saturated-fat_100g'] + df['trans-fat_100g'] > df['fat_100g'],
       ['saturated-fat_100g', 'trans-fat_100g']] = np.nan

# %% [markdown]
# **<span style="color:orange"> Les variables salt_100g et sodium_100g </span>**

# %% [markdown]
# Les valeurs de la variable "sodium_100g" ne doivent pas être plus grandes que celles de la variable "salt_100g" (et les deux variables doivent être inférieures à 100).

# %%
columns = ['salt_100g', 'sodium_100g']
for column in columns:
    df = my_net.nan_seuil(df, column, 100, "haute")
    df = my_net.nan_seuil(df, column, 0, "basse")

df.loc[df['sodium_100g'] > df['salt_100g'], ['sodium_100g']] = np.nan

# %% [markdown]
# **<span style="color:orange"> Les variables cholesterol_100g , carbohydrates_100g , sugars_100g, fiber_100g, proteins_100g , vitamin-a_100g , vitamin-c_100g , calcium_100g, et iron_100g </span>**

# %% [markdown]
# Les valeurs de ces variables ne doivent jamais dépasser 100 ni être négatives.

# %%
columns = [
    'cholesterol_100g', 'carbohydrates_100g', 'sugars_100g', 'fiber_100g',
    'proteins_100g', 'vitamin-a_100g', 'vitamin-c_100g', 'calcium_100g',
    'iron_100g'
]
for column in columns:
    df = my_net.nan_seuil(df, column, 100, "haute")
    df = my_net.nan_seuil(df, column, 0, "basse")

# %% [markdown]
# ### 1.4.2. Imputation des valeurs manquantes des variables quantitatives

# %% [markdown]
# Afin de décider si les valeurs manquantes doivent être remplacées par des médianes ou des moyennes, il faut détecter les variables qui ont un taux de valeurs aberrantes supérieur à 5% et celles qui ont un taux de valeurs aberrantes inférieur à 5%.

# %%
df.select_dtypes(exclude='object').columns
# Out:
# Index(['additives_n', 'ingredients_from_palm_oil_n',
#        'ingredients_that_may_be_from_palm_oil_n', 'energy_100g', 'fat_100g',
#        'saturated-fat_100g', 'trans-fat_100g', 'cholesterol_100g',
#        'carbohydrates_100g', 'sugars_100g', 'fiber_100g', 'proteins_100g',
#        'salt_100g', 'sodium_100g', 'vitamin-a_100g', 'vitamin-c_100g',
#        'calcium_100g', 'iron_100g', 'nutrition-score-fr_100g',
#        'serving_size_g_ou_ml', 'year'],
#       dtype='object')

# %%
'''
Affichage d'un tableau avec le nombre de outliers par variable et sépare les variables en fonction de leur taux de outliers (inférieur à 5% et supérieur à 5%)

Entrées :
data : le dataframe
colonnes_sup : les colonnes écartées de la détermination
affichage : si 'oui', affiche le tableau des variables et leurs taux de outliers

Renvoie :
- col_moins_5 : la liste des colonne ayant moins de 5% de outliers
- col_plus_5 : la liste des variables ayant plus de 5 % de outliers

'''

# Affichage d'un tableau avec le nombre de outliers par variable et liste des variables en fonction de leur taux de outliers (inférieur à 5% et supérieur à 5%)
my_desc.tableau_outliers(df, ['nutrition-score-fr_100g', 'year'], affichage="oui")
# Out:
# *Fonction by Sandy M.*
#                                          Nombre_de_outliers  Taux_de_outliers
# vitamin-c_100g                                        21311              8.15
# serving_size_g_ou_ml                                  21254              8.13
# cholesterol_100g                                      19859              7.60
# saturated-fat_100g                                    16283              6.23
# vitamin-a_100g                                        15951              6.10
# sodium_100g                                           15534              5.94
# salt_100g                                             15485              5.92
# sugars_100g                                           14387              5.50
# fiber_100g                                            13512              5.17
# proteins_100g                                         11775              4.50
# calcium_100g                                          11497              4.40
# ...

# %% [markdown]
# Les valeurs manquantes des variables qui ont un taux de valeurs aberrantes inférieur à 5% sont remplacées par des moyennes (moyennes par regroupement de catégories).

# %% [markdown]
# Les valeurs manquantes des variables qui ont un taux de valeurs aberrantes supérieur à 5% sont remplacées par des moyennes (moyennes par regroupement de catégories).

# %%
''' Cette fonction permet de remplacer les nan des variables par 
- la moyenne quand le pourcentage de outliers de la variable est inférieur à 5%
- la médiane quand le pourcentade de outliers de la variable est supérieur à 5%
Entrées :
data : le dataframe
colonnes_sup : les colonnes écartées de la détermination
Affinages : la liste des affinages pour les imputations
'''

# Remplacement des nan des variables par la moyenne ou la médiane suivant leur taux de outliers et affichage d'un tableau qui montre le nombre de valeurs manquantes après chaque affinage
df = my_net.imputation_et_tableau(df, ['nutrition-score-fr_100g', 'year'], sp3.Affinages)
# Out:
# *Fonction by Sandy M.*
# Affinage :  ['pnns_groups_1', 'pnns_groups_2', 'nutriscore_grade']  : ok
# Affinage :  ['pnns_groups_1', 'pnns_groups_2', 'brands']  : ok
# Affinage :  ['pnns_groups_1', 'main_category']  : ok
# Affinage :  ['pnns_groups_1', 'pnns_groups_2']  : ok
# Affinage :  ['pnns_groups_2']  : ok
# Affinage :  ['pnns_groups_1']  : ok
#                                          Avant_affinage  Affinage_1  \
# additives_n                                       25813           1
# ingredients_from_palm_oil_n                       25813           1
# ingredients_that_may_be_from_palm_oil_n           25813           1
# energy_100g                                       14597           0
# fat_100g                                          31601           1
# trans-fat_100g                                   126337        5283
# carbohydrates_100g                                31926           1
# proteins_100g                                     15648           1
# ...

# %% [markdown]
# Il faut faire attention à ce que certaines valeurs restent entières.

# %%
df = df.round({
    'ingredients_from_palm_oil_n': 0,
    'ingredients_that_may_be_from_palm_oil_n': 0,
    'additives_n': 0
})

# %%
columns_int = [
    'ingredients_from_palm_oil_n', 'ingredients_that_may_be_from_palm_oil_n',
    'additives_n'
]
for column in columns_int:
    df[column] = df[column].convert_dtypes(convert_integer=True)

# %% [markdown]
# Les valeurs manquantes de toutes les variables quantitatives (mis à part le nutriscore) ont été correctement imputées. Il reste à remplir les valeurs manquantes du nutriscore.

# %% [markdown]
# ### 1.4.3. Calcul et imputation des nutriscores manquants

# %% [markdown]
# **<span style="color:orange"> La variable nutrition_grade_fr </span>**

# %% [markdown]
# Pour déterminer les valeurs manquantes de la variable "nutrition_grade" il faut calculer les valeurs manquantes de la variable "nutriscore_score". Pour le calculer, la première étape est de savoir si le produit est une boisson ou un aliment. Il faut se servir de la variable "pnns_groups_2" pour le déterminer.

# %% [markdown]
# La deuxième étape consiste à déterminer la proportion de fruits et légumes du produit. Là encore, il faut se servir de la variable "pnns_groups_2" pour effectuer un classement.

# %%
''' Cette fonction détermine si le produit est une boisson ou un aliment (variable 'boisson_ou_aliment')
et la proportion de fruits et légumes (variable 'score_fruits_vegetables')

Entrées :
- df : le dataframe

Renvoie :
- df : le dataframe avec les deux nouvelles variables : 'boisson_ou_aliment' et 'score_fruits_vegetables'
'''

df = sp3.df_type_aliment(df)
df['boisson_ou_aliment'].value_counts()
# Out:
# *Fonction by Sandy M.*
# aliment    250360
# boisson     11073
# Name: boisson_ou_aliment, dtype: int64

# %%
df['score_fruits_vegetables'].value_counts()
# Out:
# 3    197126
# 0     36574
# 5     14898
# 1     12369
# 4       466
# Name: score_fruits_vegetables, dtype: int64

# %% [markdown]
# La variable "nutriscore_score" est calculée pour toutes les lignes à l'aide d'une fonction. La variable "nutriscore_grade" est déterminée suivant le résultat du calcul de la variable "nutriscore_score". Les résultats sont stockés dans deux nouvelles variables.

# %%
# La fonction calcul_nutri_score calcule le score nutritionnel d'une ligne
df['nutri_score_new'] = df.apply(lambda row: sp3.calcul_nutri_score(row), axis=1)
# La fonction calc_nutri_score_lettre donne la nutri-score pour une ligne
df['nutri_score_grade_new'] = df.apply(
    lambda row: sp3.calc_nutri_score_lettre(row), axis=1)

# %% [markdown]
# Afin de déterminer la fiabilité du calcul, les résultats obtenus sont comparés aux valeurs déjà renseignées dans la base de données dans la variable "nutriscore_grade".

# %%
''' Cette fonction calcule la fiabilité du calcul du nutriscore par rapport à des produits déjà notés
Entrées :
- df : le dataframe
'''
# calcul de la fiabilité du nutriscore calculé
sp3.fiabilite_nutriscore(df)
# Out:
# *Fonction by Sandy M.*
# Le calcul du nutriscore est fiable à  42.0 %.

# %% [markdown]
# Les valeurs manquantes sont imputées avec les valeurs calculées.

# %%
df['nutriscore_grade'] = df['nutriscore_grade'].replace({'unknown': np.nan})
df['nutriscore_grade'] = df['nutriscore_grade'].fillna(
    df['nutri_score_grade_new'])
df['nutriscore_score'] = df['nutrition-score-fr_100g'].fillna(
    df['nutri_score_new'])
df = df.drop(columns=[
    'nutri_score_grade_new', 'nutri_score_new', 'test_nutriscore',
    'nutriscore_testé', 'nutrition-score-fr_100g'
])

# %%
df['nutriscore_grade'] = df['nutriscore_grade'].str.capitalize()

# %%
print(f"La base de données contient {df.shape[0]} lignes et "
      f"{df.shape[1]} variables")
# Out:
# La base de données contient 261433 lignes et 37 variables

# %% [markdown]
# # Récapitulatif des bases de données

# %%
df.head()  # Base de données principale
# Out:
#             code   created_t                       product_name generic_name  \
# 1  0000000004530  1489069957     Banana Chips Sweetened (Whole)      unknown
# 2  0000000004559  1489069957                            Peanuts      unknown
# 3  0000000016087  1489055731             Organic Salted Nut Mix      unknown
# 4  0000000016094  1489055653                    Organic Polenta      unknown
# 5  0000000016100  1489055651  Breadshop Honey Gone Nuts Granola      unknown
#
#            brands manufacturing_places   labels purchase_places   countries  \
# 1         unknown              unknown  Unknown         unknown  Etats-Unis
# 2    torn-glasser              unknown  Unknown         unknown  Etats-Unis
# 3       grizzlies              unknown  Unknown         unknown  Etats-Unis
# 4  bob-s-red-mill              unknown  Unknown         unknown  Etats-Unis
# 5            unfi              unknown  Unknown         unknown  Etats-Unis
#
# ...

# %%
my_desc.data_informations(df)
# Out:
# *Fonction by Sandy M.*
# ---------------------------INFORMATION SUR LA BASE DE DONNEES------            -----------------------------------------
# Nombre de variables : 37
# Nombre d'observations : 261433
# ---------------------------VALEURS MANQUANTES-----------------------            ----------------------------------------
# Nombre de cellules avec des données manquantes :  0
# Pourcentage du nombre de cellules avec des données manquantes :  0.0  %
# Nombre de lignes avec au moins une donnée manquante :  0
# Pourcentage de lignes avec au moins une donnée manquante :  0.0  %
# ---------------------------VALEURS DUPLIQUEES----------------------            -----------------------------------------
# Nombre de doublons dans la base de données :  0
# Pourcentage de doublons dans la base de données :  0.0  %
# ---------------------------VALEURS OUTLIERS------------------------            -----------------------------------------
# Nombre de cellules avec des outliers :  392823
# ...

# %%
my_desc.graphique_remplissage(df, 10)

# %%
print(
    f"La base de données contient {df.select_dtypes(exclude='object').shape[1]} variables quantitatives",
    f" et {df.select_dtypes(include='object').shape[1]} variables qualitatives"
)
# Out:
# La base de données contient 22 variables quantitatives  et 15 variables qualitatives

# %%
compte_additifs.head(
)  # Base de données qui donne le nombre d'additifs dans l'ensemble de la base de données df
# Out:
#   Nom_Additif  Nombre
# 0     Unknown  114971
# 1        E330   42286
# 2        E322   25555
# 3        E101   21459
# 4        E375   21427

# %%
compte_ingredients['Nom_Ingredient'] = compte_ingredients[
    'Nom_Ingredient'].str.lower()
compte_ingredients.head(
)  # Base de données qui donne le nombre d'additifs dans l'ensemble de la base de données df
# Out:
#   Nom_Ingredient  Nombre
# 0           salt  124103
# 1          sugar   78596
# 2          water   72120
# 3        unknown   25813
# 4    citric acid   22811

# %%
data_pnns.head()
# Out:
#         Groupement 02  Nombre         Groupement 01
# 0             Unknown  196975                 Autre
# 1      One-dish meals    5289       Composite foods
# 2  Biscuits and cakes    4285         Sugary snacks
# 3              Sweets    4114         Sugary snacks
# 4             Cereals    3839  Cereals and potatoes

# %% [markdown]
# Les bases de données sont prêtes à nous aider à faire des analyses univariées et multivariées de nos données.
#
# C'est l'objet du notebook suivant.
